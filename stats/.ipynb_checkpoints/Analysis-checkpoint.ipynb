# %%
import pandas as pd

# %%
# Import stats
FILE = 'cleaned_stats.csv'

# %%
df = pd.read_csv(FILE)

# %%
df
# Out:
#      dimension  rand_degree heuristic function    time       steps
# 0            3            5                 h1     7.0       5.415
# 1            3            5                 h1     5.0       1.665
# 2            3            5                 h1     7.0       4.130
# 3            3            5                 h1     5.0       0.935
# 4            3            5                 h1     6.0       1.495
# 5            3            5                 h1     5.0       0.970
# 6            3            5                 h1     7.0       3.255
# 7            3            5                 h1     5.0       1.895
# 8            3            5                 h1     6.0       2.375
# 9            3            5                 h1     5.0       0.615
# 10           4            5                 h1     7.0       2.530
# 11           4            5                 h1     6.0       1.845
# 12           4            5                 h1     5.0       1.270
# ...

# %%
df.describe()
# Out:
#         dimension  rand_degree         time          steps
# count  180.000000   180.000000   146.000000     180.000000
# mean     4.000000    10.000000   570.753425   23449.596833
# std      0.818774     4.093871  1103.705749   45984.324971
# min      3.000000     5.000000     5.000000       0.540000
# 25%      3.000000     5.000000     5.000000       2.106250
# 50%      4.000000    10.000000    10.000000      33.195000
# 75%      5.000000    15.000000   472.250000   19023.720000
# max      5.000000    15.000000  4686.000000  175237.310000

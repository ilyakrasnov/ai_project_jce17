# %%
import pandas as pd

# %%
# Import stats
FILE = 'cleaned_stats.csv'
JSON = '../stats.json'

# %%
#df = pd.read_csv(FILE)
df = pd.read_json(JSON)

# %%
del df['board']
df
# Out:
#      dimension  heuristic  rand_degree   steps        time
# 0            3          1            5     7.0       5.575
# 1            3          2            5     5.0       4.460
# 2            3          1            5     5.0       2.160
# 3            3          2            5     5.0       1.275
# 4            3          1            5     5.0       1.225
# 5            3          2            5     5.0       1.795
# 6            3          1            5     7.0       1.440
# 7            3          2            5     5.0       1.240
# 8            3          1            5    16.0       6.130
# 9            3          2            5     5.0       1.050
# 10           3          1            5     5.0       0.745
# 11           3          2            5     5.0       0.820
# 12           3          1            5     8.0       3.460
# 13           3          2            5     5.0       0.710
# 14           3          1            5     5.0       1.260
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.factorplot(x='dimension', y='steps', data=df, hue='rand_degree', col='heuristic')

# %%
g = sns.FacetGrid(data=df, row='dimension', col='rand_degree', hue='heuristic', sharex=True, sharey=True)
g =(g.map(sns.pointplot, "steps", "time").add_legend())

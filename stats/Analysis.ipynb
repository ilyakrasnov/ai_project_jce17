# %%
import pandas as pd

# %%
# Import stats
FILE = 'cleaned_stats.csv'
JSON = '../stats.json'

# %%
#df = pd.read_csv(FILE)
df = pd.read_json(JSON)

# %%
del df['board']
df
# Out:
#      dimension  heuristic  rand_degree   steps        time
# 0            3          1            5     7.0       5.575
# 1            3          2            5     5.0       4.460
# 2            3          1            5     5.0       2.160
# 3            3          2            5     5.0       1.275
# 4            3          1            5     5.0       1.225
# 5            3          2            5     5.0       1.795
# 6            3          1            5     7.0       1.440
# 7            3          2            5     5.0       1.240
# 8            3          1            5    16.0       6.130
# 9            3          2            5     5.0       1.050
# 10           3          1            5     5.0       0.745
# 11           3          2            5     5.0       0.820
# 12           3          1            5     8.0       3.460
# 13           3          2            5     5.0       0.710
# 14           3          1            5     5.0       1.260
# 15           3          2            5     5.0       2.155
# 16           3          1            5     6.0       0.825
# 17           3          2            5     5.0       0.665
# 18           3          1            5    11.0       1.805
# 19           3          2            5     5.0       0.645
# 20           4          1            5     6.0       1.590
# 21           4          2            5     5.0       2.310
# 22           4          1            5     5.0       1.380
# 23           4          2            5     5.0       7.925
# 24           4          1            5     5.0       1.185
# 25           4          2            5     5.0       1.020
# 26           4          1            5     7.0       1.855
# 27           4          2            5     5.0       1.085
# 28           4          1            5     5.0       1.265
# 29           4          2            5     5.0       1.130
# ..         ...        ...          ...     ...         ...
# 150          4          1           15     NaN  324062.420
# 151          4          2           15  3183.0   32606.280
# 152          4          1           15     NaN  338100.015
# 153          4          2           15  6871.0  155653.765
# 154          4          1           15  6564.0  127332.530
# 155          4          2           15   884.0    2340.250
# 156          4          1           15  7799.0  171075.290
# 157          4          2           15  1785.0    9440.400
# 158          4          1           15     NaN  326971.610
# 159          4          2           15     NaN  329923.705
# 160          5          1           15     NaN  716084.730
# 161          5          2           15     NaN  731192.970
# 162          5          1           15     NaN  729691.450
# 163          5          2           15  2222.0   41688.065
# 164          5          1           15    73.0      80.225
# 165          5          2           15    15.0       4.410
# 166          5          1           15     NaN  750888.860
# 167          5          2           15     NaN  806943.255
# 168          5          1           15     NaN  814953.105
# 169          5          2           15  9717.0  727450.065
# 170          5          1           15     NaN  662539.560
# 171          5          2           15  1226.0   13429.445
# 172          5          1           15     NaN  731043.710
# 173          5          2           15     NaN  689730.595
# 174          5          1           15     NaN  787676.730
# 175          5          2           15     NaN  796853.610
# 176          5          1           15  6831.0  324557.960
# 177          5          2           15  6603.0  295265.440
# 178          5          1           15     NaN  676044.740
# 179          5          2           15     NaN  670341.920
#
# [180 rows x 5 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.factorplot(x='dimension', y='steps', data=df, hue='rand_degree', col='heuristic')

# %%
sns.factorplot(x='dimension', y='time', data=df, hue='rand_degree', col='heuristic')

# %%
g = sns.FacetGrid(data=df, row='dimension', col='heuristic', hue='rand_degree', sharex=True, sharey=True)
g =(g.map(sns.pointplot, "time", "steps").add_legend())

# %%
sns.stripplot(x="rand_degree", y="steps", data=df, jitter=True, hue="dimension");

# %%
sns.stripplot(x="rand_degree", y="time", data=df, jitter=True, hue="dimension");

# %%
sns.stripplot(x="dimension", y="steps", data=df, jitter=True, hue="rand_degree");

# %%
sns.stripplot(x="dimension", y="time", data=df, jitter=True, hue="rand_degree");

# %%
sns.swarmplot(x="dimension", y="steps", data=df, hue="rand_degree");

# %%
sns.swarmplot(x="dimension", y="time", data=df, hue="rand_degree");

# %%
sns.swarmplot(x="rand_degree", y="steps", data=df, hue="dimension");

# %%
sns.swarmplot(x="rand_degree", y="time", data=df, hue="dimension");

# %%
sns.boxplot(x="rand_degree", y="steps", data=df, hue="dimension");

# %%
sns.boxplot(x="rand_degree", y="time", data=df, hue="dimension");

# %%
sns.boxplot(x="dimension", y="steps", data=df, hue="rand_degree");

# %%
sns.boxplot(x="dimension", y="time", data=df, hue="rand_degree");

# %%
sns.lmplot(x="steps", y="time", hue="dimension", col="heuristic", data=df)

# %%
sns.lmplot(x="steps", y="time", row="dimension", col="heuristic", hue="rand_degree",data=df)

# %%
sns.lmplot(x="steps", y="time", hue="dimension", col="heuristic", row="rand_degree", data=df)

# %%
sns.distplot(df['time'], bins=5)
# Out:
# /Users/ilyakrasnov/anaconda/lib/python3.6/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
sns.lmplot(y="time", x="steps", col="dimension", row="rand_degree", data=df)

# %%
sns.lmplot(y="steps", x="dimension", col="dimension", row="heuristic",hue="rand_degree", data=df)

# %%
sns.lmplot(y="steps", x="dimension", hue="dimension", row="rand_degree", col="heuristic", data=df,  x_jitter=.1)
